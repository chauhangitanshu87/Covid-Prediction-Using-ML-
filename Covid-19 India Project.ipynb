# %%
import pandas as pd
from matplotlib import pyplot as plt 
import datetime as dt
import numpy as np
import seaborn as sns

# %%
#importing main dataset 
df = pd.read_csv('covid_19_india.csv', parse_dates=['Date'], dayfirst=True)

# %%
#keeping only required columns
df = df[['Date', 'State/UnionTerritory','Cured','Deaths','Confirmed']]
#renaming column names
df.columns = ['date', 'state','cured','deaths','confirmed']

# %%
df.head()
# Out:
#         date   state  cured  deaths  confirmed
# 0 2020-01-30  Kerala      0       0          1
# 1 2020-01-31  Kerala      0       0          1
# 2 2020-02-01  Kerala      0       0          2
# 3 2020-02-02  Kerala      0       0          3
# 4 2020-02-03  Kerala      0       0          3

# %%
#Looking at the earlier dates
df.head()
# Out:
#         date   state  cured  deaths  confirmed
# 0 2020-01-30  Kerala      0       0          1
# 1 2020-01-31  Kerala      0       0          1
# 2 2020-02-01  Kerala      0       0          2
# 3 2020-02-02  Kerala      0       0          3
# 4 2020-02-03  Kerala      0       0          3

# %%
#looking at the latest dates
df.tail()
# Out:
#             date          state    cured  deaths  confirmed
# 18105 2021-08-11      Telangana   638410    3831     650353
# 18106 2021-08-11        Tripura    77811     773      80660
# 18107 2021-08-11    Uttarakhand   334650    7368     342462
# 18108 2021-08-11  Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11    West Bengal  1506532   18252    1534999

# %%
#current date
today = df[df.date == '2021-08-11']

# %%
today
# Out:
#             date                                     state  ...  deaths  confirmed
# 18074 2021-08-11               Andaman and Nicobar Islands  ...     129       7548
# 18075 2021-08-11                            Andhra Pradesh  ...   13564    1985182
# 18076 2021-08-11                         Arunachal Pradesh  ...     248      50605
# 18077 2021-08-11                                     Assam  ...    5420     576149
# 18078 2021-08-11                                     Bihar  ...    9646     725279
# 18079 2021-08-11                                Chandigarh  ...     811      61992
# 18080 2021-08-11                              Chhattisgarh  ...   13544    1003356
# 18081 2021-08-11  Dadra and Nagar Haveli and Daman and Diu  ...       4      10654
# 18082 2021-08-11                                     Delhi  ...   25068    1436852
# 18083 2021-08-11                                       Goa  ...    3164     172085
# 18084 2021-08-11                                   Gujarat  ...   10077     825085
# 18085 2021-08-11                                   Haryana  ...    9652     770114
# 18086 2021-08-11                          Himachal Pradesh  ...    3537     208616
# 18087 2021-08-11                         Jammu and Kashmir  ...    4392     322771
# 18088 2021-08-11                                 Jharkhand  ...    5130     347440
# 18089 2021-08-11                                 Karnataka  ...   36848    2921049
# 18090 2021-08-11                                    Kerala  ...   18004    3586693
# 18091 2021-08-11                                    Ladakh  ...     207      20411
# 18092 2021-08-11                               Lakshadweep  ...      51      10263
# 18093 2021-08-11                            Madhya Pradesh  ...   10514     791980
# 18094 2021-08-11                               Maharashtra  ...  134201    6363442
# 18095 2021-08-11                                   Manipur  ...    1664     105424
# 18096 2021-08-11                                 Meghalaya  ...    1185      69769
# 18097 2021-08-11                                   Mizoram  ...     171      46320
# 18098 2021-08-11                                  Nagaland  ...     585      28811
# 18099 2021-08-11                                    Odisha  ...    6565     988997
# 18100 2021-08-11                                Puducherry  ...    1800     121766
# 18101 2021-08-11                                    Punjab  ...   16322     599573
# 18102 2021-08-11                                 Rajasthan  ...    8954     953851
# 18103 2021-08-11                                    Sikkim  ...     356      28018
# 18104 2021-08-11                                Tamil Nadu  ...   34367    2579130
# 18105 2021-08-11                                 Telangana  ...    3831     650353
# 18106 2021-08-11                                   Tripura  ...     773      80660
# 18107 2021-08-11                               Uttarakhand  ...    7368     342462
# 18108 2021-08-11                             Uttar Pradesh  ...   22775    1708812
# 18109 2021-08-11                               West Bengal  ...   18252    1534999
#
# [36 rows x 5 columns]

# %%
#Sorting data w.r.t number of confirmed cases
max_confirmed_cases=today.sort_values(by="confirmed",ascending=False)
max_confirmed_cases
# Out:
#             date                                     state  ...  deaths  confirmed
# 18094 2021-08-11                               Maharashtra  ...  134201    6363442
# 18090 2021-08-11                                    Kerala  ...   18004    3586693
# 18089 2021-08-11                                 Karnataka  ...   36848    2921049
# 18104 2021-08-11                                Tamil Nadu  ...   34367    2579130
# 18075 2021-08-11                            Andhra Pradesh  ...   13564    1985182
# 18108 2021-08-11                             Uttar Pradesh  ...   22775    1708812
# 18109 2021-08-11                               West Bengal  ...   18252    1534999
# 18082 2021-08-11                                     Delhi  ...   25068    1436852
# 18080 2021-08-11                              Chhattisgarh  ...   13544    1003356
# 18099 2021-08-11                                    Odisha  ...    6565     988997
# 18102 2021-08-11                                 Rajasthan  ...    8954     953851
# 18084 2021-08-11                                   Gujarat  ...   10077     825085
# 18093 2021-08-11                            Madhya Pradesh  ...   10514     791980
# 18085 2021-08-11                                   Haryana  ...    9652     770114
# 18078 2021-08-11                                     Bihar  ...    9646     725279
# 18105 2021-08-11                                 Telangana  ...    3831     650353
# 18101 2021-08-11                                    Punjab  ...   16322     599573
# 18077 2021-08-11                                     Assam  ...    5420     576149
# 18088 2021-08-11                                 Jharkhand  ...    5130     347440
# 18107 2021-08-11                               Uttarakhand  ...    7368     342462
# 18087 2021-08-11                         Jammu and Kashmir  ...    4392     322771
# 18086 2021-08-11                          Himachal Pradesh  ...    3537     208616
# 18083 2021-08-11                                       Goa  ...    3164     172085
# 18100 2021-08-11                                Puducherry  ...    1800     121766
# 18095 2021-08-11                                   Manipur  ...    1664     105424
# 18106 2021-08-11                                   Tripura  ...     773      80660
# 18096 2021-08-11                                 Meghalaya  ...    1185      69769
# 18079 2021-08-11                                Chandigarh  ...     811      61992
# 18076 2021-08-11                         Arunachal Pradesh  ...     248      50605
# 18097 2021-08-11                                   Mizoram  ...     171      46320
# 18098 2021-08-11                                  Nagaland  ...     585      28811
# 18103 2021-08-11                                    Sikkim  ...     356      28018
# 18091 2021-08-11                                    Ladakh  ...     207      20411
# 18081 2021-08-11  Dadra and Nagar Haveli and Daman and Diu  ...       4      10654
# 18092 2021-08-11                               Lakshadweep  ...      51      10263
# 18074 2021-08-11               Andaman and Nicobar Islands  ...     129       7548
#
# [36 rows x 5 columns]

# %%
#Getting states with maximum number of confirmed cases
top_states_confirmed=max_confirmed_cases[0:10]

# %%
#Making bar-plot for states with top confirmed cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state",y="confirmed",data=top_states_confirmed,hue="state")
plt.show()

# %%
#Sorting data w.r.t number of death cases
max_death_cases=today.sort_values(by="deaths",ascending=False)
max_death_cases
# Out:
#             date                                     state  ...  deaths  confirmed
# 18094 2021-08-11                               Maharashtra  ...  134201    6363442
# 18089 2021-08-11                                 Karnataka  ...   36848    2921049
# 18104 2021-08-11                                Tamil Nadu  ...   34367    2579130
# 18082 2021-08-11                                     Delhi  ...   25068    1436852
# 18108 2021-08-11                             Uttar Pradesh  ...   22775    1708812
# 18109 2021-08-11                               West Bengal  ...   18252    1534999
# 18090 2021-08-11                                    Kerala  ...   18004    3586693
# 18101 2021-08-11                                    Punjab  ...   16322     599573
# 18075 2021-08-11                            Andhra Pradesh  ...   13564    1985182
# 18080 2021-08-11                              Chhattisgarh  ...   13544    1003356
# 18093 2021-08-11                            Madhya Pradesh  ...   10514     791980
# 18084 2021-08-11                                   Gujarat  ...   10077     825085
# 18085 2021-08-11                                   Haryana  ...    9652     770114
# 18078 2021-08-11                                     Bihar  ...    9646     725279
# 18102 2021-08-11                                 Rajasthan  ...    8954     953851
# 18107 2021-08-11                               Uttarakhand  ...    7368     342462
# 18099 2021-08-11                                    Odisha  ...    6565     988997
# 18077 2021-08-11                                     Assam  ...    5420     576149
# 18088 2021-08-11                                 Jharkhand  ...    5130     347440
# 18087 2021-08-11                         Jammu and Kashmir  ...    4392     322771
# 18105 2021-08-11                                 Telangana  ...    3831     650353
# 18086 2021-08-11                          Himachal Pradesh  ...    3537     208616
# 18083 2021-08-11                                       Goa  ...    3164     172085
# 18100 2021-08-11                                Puducherry  ...    1800     121766
# 18095 2021-08-11                                   Manipur  ...    1664     105424
# 18096 2021-08-11                                 Meghalaya  ...    1185      69769
# 18079 2021-08-11                                Chandigarh  ...     811      61992
# 18106 2021-08-11                                   Tripura  ...     773      80660
# 18098 2021-08-11                                  Nagaland  ...     585      28811
# 18103 2021-08-11                                    Sikkim  ...     356      28018
# 18076 2021-08-11                         Arunachal Pradesh  ...     248      50605
# 18091 2021-08-11                                    Ladakh  ...     207      20411
# 18097 2021-08-11                                   Mizoram  ...     171      46320
# 18074 2021-08-11               Andaman and Nicobar Islands  ...     129       7548
# 18092 2021-08-11                               Lakshadweep  ...      51      10263
# 18081 2021-08-11  Dadra and Nagar Haveli and Daman and Diu  ...       4      10654
#
# [36 rows x 5 columns]

# %%
#Getting states with maximum number of death cases
top_states_death=max_death_cases[0:10]

# %%
#Making bar-plot for states with top death cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state",y="deaths",data=top_states_death,hue="state")
plt.show()

# %%
#Sorting data w.r.t number of cured cases
max_cured_cases=today.sort_values(by="cured",ascending=False)
max_cured_cases
# Out:
#             date                                     state  ...  deaths  confirmed
# 18094 2021-08-11                               Maharashtra  ...  134201    6363442
# 18090 2021-08-11                                    Kerala  ...   18004    3586693
# 18089 2021-08-11                                 Karnataka  ...   36848    2921049
# 18104 2021-08-11                                Tamil Nadu  ...   34367    2579130
# 18075 2021-08-11                            Andhra Pradesh  ...   13564    1985182
# 18108 2021-08-11                             Uttar Pradesh  ...   22775    1708812
# 18109 2021-08-11                               West Bengal  ...   18252    1534999
# 18082 2021-08-11                                     Delhi  ...   25068    1436852
# 18080 2021-08-11                              Chhattisgarh  ...   13544    1003356
# 18099 2021-08-11                                    Odisha  ...    6565     988997
# 18102 2021-08-11                                 Rajasthan  ...    8954     953851
# 18084 2021-08-11                                   Gujarat  ...   10077     825085
# 18093 2021-08-11                            Madhya Pradesh  ...   10514     791980
# 18085 2021-08-11                                   Haryana  ...    9652     770114
# 18078 2021-08-11                                     Bihar  ...    9646     725279
# 18105 2021-08-11                                 Telangana  ...    3831     650353
# 18101 2021-08-11                                    Punjab  ...   16322     599573
# 18077 2021-08-11                                     Assam  ...    5420     576149
# 18088 2021-08-11                                 Jharkhand  ...    5130     347440
# 18107 2021-08-11                               Uttarakhand  ...    7368     342462
# 18087 2021-08-11                         Jammu and Kashmir  ...    4392     322771
# 18086 2021-08-11                          Himachal Pradesh  ...    3537     208616
# 18083 2021-08-11                                       Goa  ...    3164     172085
# 18100 2021-08-11                                Puducherry  ...    1800     121766
# 18095 2021-08-11                                   Manipur  ...    1664     105424
# 18106 2021-08-11                                   Tripura  ...     773      80660
# 18096 2021-08-11                                 Meghalaya  ...    1185      69769
# 18079 2021-08-11                                Chandigarh  ...     811      61992
# 18076 2021-08-11                         Arunachal Pradesh  ...     248      50605
# 18097 2021-08-11                                   Mizoram  ...     171      46320
# 18098 2021-08-11                                  Nagaland  ...     585      28811
# 18103 2021-08-11                                    Sikkim  ...     356      28018
# 18091 2021-08-11                                    Ladakh  ...     207      20411
# 18081 2021-08-11  Dadra and Nagar Haveli and Daman and Diu  ...       4      10654
# 18092 2021-08-11                               Lakshadweep  ...      51      10263
# 18074 2021-08-11               Andaman and Nicobar Islands  ...     129       7548
#
# [36 rows x 5 columns]

# %%
#Getting states with maximum number of cured cases
top_states_cured=max_cured_cases[0:10]

# %%
#Making bar-plot for states with top death cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state",y="cured",data=top_states_cured,hue="state")
plt.show()

# %%
#Maharashtra
maha = df[df.state == 'Maharashtra']

# %%
maha
# Out:
#             date        state    cured  deaths  confirmed
# 76    2020-03-09  Maharashtra        0       0          2
# 91    2020-03-10  Maharashtra        0       0          5
# 97    2020-03-11  Maharashtra        0       0          2
# 120   2020-03-12  Maharashtra        0       0         11
# 133   2020-03-13  Maharashtra        0       0         14
# ...          ...          ...      ...     ...        ...
# 17950 2021-08-07  Maharashtra  6130137  133717    6341759
# 17986 2021-08-08  Maharashtra  6139493  133845    6347820
# 18022 2021-08-09  Maharashtra  6144388  133996    6353328
# 18058 2021-08-10  Maharashtra  6151956  134064    6357833
# 18094 2021-08-11  Maharashtra  6159676  134201    6363442
#
# [520 rows x 5 columns]

# %%
#Visualizing confirmed cases in maharashtra
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="confirmed",data=maha,color="g")
plt.show()

# %%
#Visualizing death cases in maharashtra
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="deaths",data=maha,color="r")
plt.show()

# %%
#Uttar Pradesh
Up= df[df.state == 'Uttar Pradesh']
Up
# Out:
#             date          state    cured  deaths  confirmed
# 39    2020-03-04  Uttar Pradesh        0       0          6
# 50    2020-03-05  Uttar Pradesh        0       0          7
# 55    2020-03-06  Uttar Pradesh        0       0          7
# 58    2020-03-07  Uttar Pradesh        0       0          7
# 72    2020-03-08  Uttar Pradesh        0       0          7
# ...          ...            ...      ...     ...        ...
# 17964 2021-08-07  Uttar Pradesh  1685299   22771    1708689
# 18000 2021-08-08  Uttar Pradesh  1685357   22773    1708716
# 18036 2021-08-09  Uttar Pradesh  1685406   22773    1708772
# 18072 2021-08-10  Uttar Pradesh  1685449   22774    1708793
# 18108 2021-08-11  Uttar Pradesh  1685492   22775    1708812
#
# [526 rows x 5 columns]

# %%
#Visualizing confirmed cases in up
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="confirmed",data=Up,color="g")
plt.show()

# %%
#Visualizing death cases in up
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="deaths",data=Up,color="r")
plt.show()

# %%
#Checking state-wise testing details
tests = pd.read_csv('StatewiseTestingDetails.csv')
tests
# Out:
#              Date                        State  TotalSamples Negative  Positive
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# ...           ...                          ...           ...      ...       ...
# 16331  2021-08-06                  West Bengal    15999961.0      NaN       NaN
# 16332  2021-08-07                  West Bengal    16045662.0      NaN       NaN
# 16333  2021-08-08                  West Bengal    16092192.0      NaN       NaN
# 16334  2021-08-09                  West Bengal    16122345.0      NaN       NaN
# 16335  2021-08-10                  West Bengal    16162814.0      NaN       NaN
#
# [16336 rows x 5 columns]

# %%
test_latest =  tests[tests.Date == '2020-08-10']

# %%
test_latest
# Out:
#              Date                                     State  ...  Negative  Positive
# 88     2020-08-10               Andaman and Nicobar Islands  ...       NaN    1625.0
# 575    2020-08-10                            Andhra Pradesh  ...   2298779  235525.0
# 1053   2020-08-10                         Arunachal Pradesh  ...    104171    2231.0
# 1521   2020-08-10                                     Assam  ...       NaN   61737.0
# 2010   2020-08-10                                     Bihar  ...       NaN   82741.0
# 2498   2020-08-10                                Chandigarh  ...     16246    1595.0
# 2971   2020-08-10                              Chhattisgarh  ...       NaN   12502.0
# 3438   2020-08-10  Dadra and Nagar Haveli and Daman and Diu  ...     43579       NaN
# 3630   2020-08-10                                     Delhi  ...       NaN  146134.0
# 4113   2020-08-10                                       Goa  ...       NaN    9029.0
# 4602   2020-08-10                                   Gujarat  ...    945114   72120.0
# 5092   2020-08-10                                   Haryana  ...    705790   42429.0
# 5580   2020-08-10                          Himachal Pradesh  ...    162567    3463.0
# 6069   2020-08-10                         Jammu and Kashmir  ...    700175   25367.0
# 6554   2020-08-10                                 Jharkhand  ...    368398   18786.0
# 7044   2020-08-10                                 Karnataka  ...       NaN  182354.0
# 7541   2020-08-10                                    Kerala  ...       NaN   35516.0
# 7990   2020-08-10                                    Ladakh  ...     17513    1717.0
# 8522   2020-08-10                            Madhya Pradesh  ...    865756   39891.0
# 9013   2020-08-10                               Maharashtra  ...   2241214  535635.0
# 9451   2020-08-10                                   Manipur  ...       NaN    3853.0
# 9879   2020-08-10                                 Meghalaya  ...       NaN    1114.0
# 10310  2020-08-10                                   Mizoram  ...       NaN     620.0
# 10776  2020-08-10                                  Nagaland  ...       NaN    3011.0
# 11266  2020-08-10                                    Odisha  ...       NaN   47455.0
# 11745  2020-08-10                                Puducherry  ...     41941    5624.0
# 12235  2020-08-10                                    Punjab  ...       NaN   24889.0
# 12726  2020-08-10                                 Rajasthan  ...   1699840   53670.0
# 13186  2020-08-10                                    Sikkim  ...       NaN     910.0
# 13630  2020-08-10                                Tamil Nadu  ...       NaN  302815.0
# 14053  2020-08-10                                 Telangana  ...       NaN   80751.0
# 14520  2020-08-10                                   Tripura  ...    195781    6223.0
# 14986  2020-08-10                             Uttar Pradesh  ...       NaN  126722.0
# 15477  2020-08-10                               Uttarakhand  ...    193925   10021.0
# 15970  2020-08-10                               West Bengal  ...       NaN   98459.0
#
# [35 rows x 5 columns]

# %%
#Sorting data w.r.t number of cured cases
max_tests_State=test_latest.sort_values(by="TotalSamples",ascending=False)
max_tests_State
# Out:
#              Date                                     State  ...  Negative  Positive
# 13604  2020-07-15                                Tamil Nadu  ...       NaN  151820.0
# 8987   2020-07-15                               Maharashtra  ...   1132434  280751.0
# 14961  2020-07-15                             Uttar Pradesh  ...       NaN   41383.0
# 549    2020-07-15                            Andhra Pradesh  ...   1182512   35451.0
# 12700  2020-07-15                                 Rajasthan  ...   1091930   26437.0
# 7019   2020-07-15                                 Karnataka  ...    831246   47253.0
# 3604   2020-07-15                                     Delhi  ...       NaN  116993.0
# 15944  2020-07-15                               West Bengal  ...       NaN   34427.0
# 1495   2020-07-15                                     Assam  ...       NaN   18666.0
# 8496   2020-07-15                            Madhya Pradesh  ...    516780   19643.0
# 4576   2020-07-15                                   Gujarat  ...    443059   44648.0
# 6043   2020-07-15                         Jammu and Kashmir  ...    462483   11666.0
# 7515   2020-07-15                                    Kerala  ...       NaN    9554.0
# 12209  2020-07-15                                    Punjab  ...       NaN    8799.0
# 5066   2020-07-15                                   Haryana  ...    371350   23306.0
# 11240  2020-07-15                                    Odisha  ...       NaN   14898.0
# 1984   2020-07-15                                     Bihar  ...       NaN   20173.0
# 2945   2020-07-15                              Chhattisgarh  ...       NaN    4556.0
# 14028  2020-07-15                                 Telangana  ...    169324   39342.0
# 6528   2020-07-15                                 Jharkhand  ...    191508    4562.0
# 5554   2020-07-15                          Himachal Pradesh  ...    103730    1341.0
# 15451  2020-07-15                               Uttarakhand  ...     89212    3785.0
# 4087   2020-07-15                                       Goa  ...       NaN    2951.0
# 14495  2020-07-15                                   Tripura  ...     90032    2281.0
# 9429   2020-07-15                                   Manipur  ...       NaN    1700.0
# 3415   2020-07-15  Dadra and Nagar Haveli and Daman and Diu  ...     36195     552.0
# 1027   2020-07-15                         Arunachal Pradesh  ...     32450     491.0
# 11719  2020-07-15                                Puducherry  ...     25907    1596.0
# 10750  2020-07-15                                  Nagaland  ...       NaN     902.0
# 9853   2020-07-15                                 Meghalaya  ...       NaN     346.0
# 62     2020-07-15               Andaman and Nicobar Islands  ...       NaN     176.0
# 10284  2020-07-15                                   Mizoram  ...       NaN     238.0
# 13161  2020-07-15                                    Sikkim  ...     11355       NaN
# 2472   2020-07-15                                Chandigarh  ...      9385     619.0
#
# [34 rows x 5 columns]

# %%
#Making bar-plot for states with max test cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="State",y="TotalSamples",data=max_tests_State[0:5],hue="State")
plt.show()

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
Up['date'] = Up['date'].map(dt.datetime.toordinal)
# Out:
#          date          state    cured  deaths  confirmed
# 39     737488  Uttar Pradesh        0       0          6
# 50     737489  Uttar Pradesh        0       0          7
# 55     737490  Uttar Pradesh        0       0          7
# 58     737491  Uttar Pradesh        0       0          7
# 72     737492  Uttar Pradesh        0       0          7
# ...       ...            ...      ...     ...        ...
# 17964  738009  Uttar Pradesh  1685299   22771    1708689
# 18000  738010  Uttar Pradesh  1685357   22773    1708716
# 18036  738011  Uttar Pradesh  1685406   22773    1708772
# 18072  738012  Uttar Pradesh  1685449   22774    1708793
# 18108  738013  Uttar Pradesh  1685492   22775    1708812
#
# [526 rows x 5 columns]

# %%
#getting dependent variable and inpedent variable
x=Up['date']
y=Up['confirmed']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
rf.predict([[737498]])
